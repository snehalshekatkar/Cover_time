# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('classic')
import seaborn as sns
import graph_tool.all as gt

g = gt.Graph(directed = False)
g.add_edge_list([(0, 1), (1, 2), (2, 3), (0, 4), (4, 5), (0, 6), (6, 7)])
g.save('extended_star_3_2_2.xml.gz')

# %%
df = pd.read_csv('tot_times.dat', header = None)
df2 = pd.read_csv('prob_dist.dat', header = None)
df3 = pd.read_csv('cum_dist.dat', header = None)
#df3.head()
#len(df3)

# %%
plt.hist(df[1], normed=True, alpha = 0.5, cumulative=True)
plt.plot(df3[1], linewidth = 2, color = 'k')

plt.show()

# %%
"""Spanning tree"""
g = gt.collection.data['karate']
pos = gt.sfdp_layout(g)
u = gt.GraphView(g, efilt = gt.random_spanning_tree(g))
gt.graph_draw(g, pos = pos, vertex_size = 10)
gt.graph_draw(u, pos = pos, vertex_size = 10)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f1ef68c95f8, at 0x7f1ef68b8ac8>
