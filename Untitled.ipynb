# %%
import graph_tool.all as gt
g = gt.collection.data['karate']

# %%
gt.graph_draw(g)
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7f26b02feba8, at 0x7f2668e98c18>
